# %% [markdown]
# <a href="https://colab.research.google.com/github/Lamlam44/Plant_Disease_Prediction/blob/main/Plant_Disease_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/Plant_Disease_Prediction
# Out:
# /content/Plant_Disease_Prediction

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1.04 KiB | 266.00 KiB/s, done.
# From https://github.com/Lamlam44/Plant_Disease_Prediction
#  * branch            main       -> FETCH_HEAD
#    a794421..30690ba  main       -> origin/main
# Updating a794421..30690ba
# Fast-forward
#  train.py | 48 ++++++++++++++++++++++++++++++------------------
#  1 file changed, 30 insertions(+), 18 deletions(-)

# %%
# !python train.py
# Out:
# 2026-04-08 04:39:04.537366: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775623144.722309   22959 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775623144.781120   22959 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775623145.160514   22959 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
